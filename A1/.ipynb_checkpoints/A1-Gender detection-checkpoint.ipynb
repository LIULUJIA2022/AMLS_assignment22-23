# %% [markdown]
# # ELEC0134 - Applied Machine Learning Systems Assignment

# %% [markdown]
# # Task A: Binary tasks (celeba dataset)
#
# # A1: Gender detection - male or female
#
# In this notebook, we are going to detect gender either male or female from the celeba dataset:
#
# (1)Pre-processing the images using feature extractions technique to obtain facial landmarks
#
# (2)Fit the SVM model to the training data
#
# (3)Model hyperparameter tuning for kernel parameter in Support Vector Classifiers
#
# (4)Plot the learning curve

# %% [markdown]
# ## Import libraries and define the path of folder/file

# %%
import os
import numpy as np #数据处理的库numpy
import matplotlib.pyplot as plt #matplotli库画图
from keras_preprocessing import image  #keras_preprocessing显示图像
import cv2 #Opencv库图像处理
import dlib #人脸识别的库dlib

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
from sklearn.datasets import load_iris

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit
# Out:
# /Users/liujia/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# PATH TO ALL IMAGES
global AMLS_dir, basedir, celeba_dir, img_dir, image_paths, target_size

# Modified the directory
os.chdir('..')
AMLS_dir = os.path.abspath(os.curdir)
basedir = os.path.join(AMLS_dir,'Datasets')
celeba_dir = os.path.join(basedir,'celeba')
img_dir = os.path.join(celeba_dir,'img')


labels_filename = 'labels.csv'
# labels = os.path.join(base_dir,'celeba/labels.csv') #倒入标签文件csv

print(img_dir)
# Out:
# /Users/liujia/Desktop/AMLS_22-23_SN22126076/Datasets/celeba/img

# %% [markdown]
# # 1) Pre-processing
# 图像通过预处理成数组形式，能够转化成模型输入的值

# %% [markdown]
# ## a) Feature Extraction Function
# 使用dlib库的get_frontal_face_detector模块探测出人脸，然后使用shape_predictor_68_face_landmarks.dat特征数据预测人脸特征数值。

# %%
# 68-points dlib预测器

#dlib特征提取器
detector = dlib.get_frontal_face_detector()  #使用dlib库的get_frontal_face_detector模块探测出人脸
#功能：人脸检测画框
#参数：无
#返回值：默认的人脸检测器

#加载并初始化检测器
#dlib的68点特征预测器，进行人脸 68点特征提取：
predictor = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat') #预测器
#利用Dlib官方训练好的模型“shape_predictor_68_face_landmarks.dat”进行68点标定

#利用OpenCv进行图像化处理，在人脸上画出68个点，并标明序号


# how to find frontal human faces in an image using 68 landmarks.  These are points on the face such as the corners of the mouth, along the eyebrows, on the eyes, and so forth.
# The face detector we use is made using the classic Histogram of Oriented
# Gradients (HOG) feature combined with a linear classifier, an image pyramid,
# and sliding window detection scheme.  The pose estimator was created by
# using dlib's implementation of the paper:
# One Millisecond Face Alignment with an Ensemble of Regression Trees by
# Vahid Kazemi and Josephine Sullivan, CVPR 2014
# and was trained on the iBUG 300-W face landmark dataset (see https://ibug.doc.ic.ac.uk/resources/facial-point-annotations/):
#     C. Sagonas, E. Antonakos, G, Tzimiropoulos, S. Zafeiriou, M. Pantic.
#     300 faces In-the-wild challenge: Database and results.
#     Image and Vision Computing (IMAVIS), Special Issue on Facial Landmark Localisation "In-The-Wild". 2016.
#如何使用68个地标在图像中找到正面人脸。这些是脸上的点，如嘴角、眉毛、眼睛等。
#我们使用的人脸检测器是使用经典的面向直方图
#梯度（HOG）特征与线性分类器、图像金字塔等相结合，
#以及滑动窗口检测方案。姿势估计器由以下人员创建
#使用dlib的论文实现：
#利用回归树集合的一毫秒人脸对齐
#Vahid Kazemi和Josephine Sullivan，CVPR 2014
#并在iBUG 300-W人脸标志性数据集上进行训练（参见https://ibug.doc.ic.ac.uk/resources/facial-point-annotations/):
#C.Sagonas、E.Antonakos、G、Tzimiropoulos、S.Zafeiriou、M.Pantic。
#300人面临严峻挑战：数据库和结果。
#图像和视觉计算（IMAVIS），面部地标定位“野外”专刊。2016

# %% [markdown]
# ## b)Bounding box to match the faces
# take a bounding predicted by dlib and convert it to the format (left, top, right, bottom)

# %%
def rect_to_bounding_box(rect):
  
    left = rect.left()
    top = rect.top()
    right = rect.right() - left
    bottom = rect.bottom() - top
    
    # print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(i, left, top, right, bottom))
    # print(left, top, right, bottom)

    # return a tuple of (left, top, right, bottom)
    return (left, top, right, bottom)

# %% [markdown]
# ## c)Extract landmarks at face region
# load the image, detect the landmarks of the face, and then return the image and the landmarks

# %%
def run_dlib_shape(image):
    dlibout = []
    # load the input image, resize it to uint8 type, and convert it to grayscale
    resized_image = image.astype('uint8')

    gray = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)
    
    # 再次将灰度图片转化成uint8 type
    gray = gray.astype('uint8')
    
    # detect faces in the grayscale image
    rects = detector(gray, 1)
    
    # 返回的结果是包含着检测到的人脸的方框的左上角坐标和右下角坐标
    #print(rects)
    
    num_faces = len(rects)

    # 未检测到人脸
    if num_faces == 0:
        dlibout = None
        # print('Cannot dectect a face, wrong image!')
    
    else:
        # 检测到人脸
        face_areas = np.zeros((1, num_faces))
        face_shapes = np.zeros((136, num_faces), dtype = np.int64)

        # loop over the face detections
        for (i, rect) in enumerate(rects):
            # determine the facial landmarks for the face region, then
            # convert the facial landmark (x, y)-coordinates to a NumPy array
            # 得到关键点的坐标
            temp_shape = predictor(gray, rect)
            # 此处返回的shape并不是关键点的坐标，我们需要将其中包含的坐标信息提取出来。
            temp_shape = shape_to_np(temp_shape, dtype=  'int')
            # 将shape的返回值转换为能用的坐标信息
        
            # convert dlib's rectangle to a OpenCV-style bounding box
            #  (x, y, w, h) = face_utils.rect_to_bounding_box(rect)
            (left, top, right, bottom) = rect_to_bounding_box(rect)
            face_shapes[:, i] = np.reshape(temp_shape, [136])
            face_areas[0, i] = right * bottom
        # find largest face and keep
        dlibout = np.reshape(np.transpose(face_shapes[:, np.argmax(face_areas)]), [68, 2])

    return dlibout, resized_image

# %% [markdown]
# ## d) Convert facial landmarks into Numpy array
# 将shape的返回值转换为能输入进模型的坐标信息

# %%
def shape_to_np(shape, dtype="int"):
    # initialize the list of (x, y)-coordinates
    # 创建68*2
    coords = np.zeros((shape.num_parts, 2), dtype=dtype)

    # loop over all facial landmarks and convert them into a 2-tuple of (x, y)-coordinates
    for i in range(0, shape.num_parts):
        coords[i] = (shape.part(i).x, shape.part(i).y) # 第i个关键点的横纵坐标
    # print(coords)
    # return the list of (x, y)-coordinates
    return coords

# %% [markdown]
# ## e)Extract the facial landmarks and gender label all images in celeba dataset
#  This funtion extracts the landmarks features for all images in the folder 'dataset_AMLS_22-23/celeba/img'
#
#  It also extracts the gender label for each image for all labels in the file 'dataset_AMLS_22-23/celeba/'labels.csv''
#
#     :return:
#         landmark_features:  an array containing 68 landmark points for each image in which a face was detected
#         gender_labels:      an array containing the gender label (male=0 and female=1) for each image in
#                             which a face was detected
#         right_img:          detecting 68 landmark points in the images correctly
#         wrong_img:          error detecting 68 landmark points in the images due to non-frontal faces

# %%
def extract_features_labels(img_dir, celeba_dir, labels_filename):
   
    # load the img_dir to list all images file name
    image_paths = [os.path.join(img_dir, l) for l in os.listdir(img_dir)]
    target_size = None
    # load the labels file
    labels_file = open(os.path.join(celeba_dir, labels_filename), 'r')
    # list all images gender label
    lines = labels_file.readlines() 
    gender_labels = {line.split('\t')[0] : int(line.split('\t')[2]) for line in lines[1:]}
    # smile_labels = {line.split('\t')[0] : int(line.split('\t')[3]) for line in lines[1:]}
    if os.path.isdir(img_dir):
        # 能识别到人脸的图片
        right_img = []
        
        face_features = []
        genders = []
        # smile = []
        
        # 未能识别到人脸的图片
        wrong_img = []
        
        for img_path in image_paths:
            file_name= img_path.split('.')[0].split('/')[-1]

            # load image
            img = image.img_to_array(
                image.load_img(img_path,
                               target_size=target_size,
                               interpolation='bicubic'))
            features, _ = run_dlib_shape(img)
            
            if features is not None:
                right_img.append(file_name)
                face_features.append(features)
                # print('the detector can recognize the face', file_name)
                genders.append(gender_labels[file_name])
            else:
                wrong_img.append(file_name)
                # print('the detector can recognize the face', file_name)

    landmark_features = np.array(face_features)
    gender_labels = (np.array(genders) + 1)/2 # simply converts the -1 into 0, so male=0 and female=1
    # simle_labels = (np.array(labels) + 1)/2 # simply converts the -1 into 0, so not smile=0 and smile=1
    # return 带红点的正确图名字，特征点坐标，性别标签，错误图名字
    return landmark_features, gender_labels, right_img, wrong_img

# %% [markdown]
# ## Example of an extracted images
# 通过输入img的filename，可以检查到这个图片是否可以被检测到。如果可以，画出这张图的特征点并打印每个特征点的坐标；如果不可以，则显示这张图片不可被检测器检测到，'Cannot dectect a face, wrong image!'

# %%
ex_img = os.path.join(img_dir, '5.jpg')


img = image.img_to_array(image.load_img(ex_img,
                               target_size = None,
                               interpolation = 'bicubic'))
img_features, _ = run_dlib_shape(img)
# print("ex_img:\n", img_features) 

# Load image using cv2
actual_img = cv2.imread(ex_img)
fig = plt.figure(figsize = (7,7))
fig_plot = plt.imshow(actual_img)

if img_features is not None:
  plt.title('Extracted Feature Images with Landmarks')
  plt.scatter(img_features[:,0], img_features[:,1], c = 'r') 
else:
  print('Cannot dectect a face, wrong image!')

# %% [markdown]
# ## Non-frontal face images detection
# Gender detection does not work well with some images due to non-frontal face images. The feature extraction function will error for these images and should be discarded during the model training.
# 找到不可被检测到的面部的个数，并打印它们的filename

# %%
landmarks, gender, right_image, wrong_image = extract_features_labels(img_dir, celeba_dir, labels_filename)
print('5000 images with features: ' + str(len(right_image)))
#  print('5000 images with features: ' + str(landmarks.shape[0]))
print('5000 detectable_images with labels: ' + str(gender.shape[0]))

# Print the images with failed landmarks detection
# print('wrong images with no detection:' + str((5000 - len(right_image))))
print('Not detectable images with no features and labels:' + str(len(wrong_image)))
print('wrong images with associated title: ')
print(wrong_image)
# Out:
# 5000 images with features: 4795
# 5000 detectable_images with labels: 4795
# Not detectable images with no features and labels:205
# wrong images with associated title:
# ['88', '3785', '3168', '3626', '3197', '572', '4411', '2060', '201', '149', '4758', '2261', '3625', '3382', '982', '2248', '3142', '2512', '1153', '2314', '148', '158', '1037', '2728', '1793', '4006', '165', '198', '66', '3569', '3757', '365', '4789', '1183', '1815', '2267', '239', '2919', '4401', '4830', '416', '4987', '2851', '2110', '1343', '2605', '840', '2201', '1522', '4473', '3650', '4881', '4103', '1641', '880', '1119', '3054', '4101', '1045', '1285', '3492', '4302', '1939', '4699', '3135', '4666', '4672', '315', '4712', '881', '3257', '1468', '4500', '2213', '701', '3454', '4449', '3865', '4688', '3130', '4893', '1109', '4717', '3291', '1479', '1337', '3252', '1651', '2416', '3907', '2012', '1297', '4476', '3319', '2013', '1532', '1254', '4112', '1877', '887', '4241', '35', '1305', '1649', '4080', '4447', '4335', '4309', '519', '2631', '4524', '2828', '137', '645', '123', '1676', '4322', '2975', '2961', '1703', '452', '3048', '136', '4531', '3514', '2622', '330', '3662', '4680', '1505', '2971', '4454', '2582', '292', '2347', '1666', '2145', '4522', '119', '2345', '4668', '3107', '3853', '3927', '2344', '4709', '4251', '4550', '4222', '1400', '143', '1602', '3798', '2486', '433', '1945', '2294', '2727', '2040', '4009', '3564', '626', '4745', '3823', '4802', '948', '223', '3639', '425', '2447', '3211', '2', '623', '2696', '4595', '1162', '2480', '1994', '4386', '756', '1956', '3199', '4796', '1605', '3012', '92', '3', '4555', '3979', '3945', '1015', '1997', '556', '2285', '4421', '3399', '1558', '219', '3824', '4150', '3171', '4597', '153', '4540', '806']

# %% [markdown]
# # 2) Classification
# # Support Vector Machine (SVM)
# We are going to use the dataset使用分类的SVM算法。使用scikit学习为分类任务训练SVM算法。函数img_NewSVM（），该函数构建并训练用于二进制分类的SVM算法。

# %% [markdown]
# ## a)(i) Load the landmarks and genders as training data
# We can obtain these features given an image by simply calling the previous ***extract_features_labels()*** function
#
# Using these features is optional, since there is a variety of facial landmarks detectors you could choose from. Also the same dlib framework can be used to train other facial landmark detectors or custom shape predictors.
#
# Note that we will use features extracted from images rather than images themselves.

# %%
def get_data(X, Y):
    Y = np.array([Y, -(Y - 1)]).T
    # Shuffle and split the data into training(70%) and test(30%) set 
    X, Y = shuffle(X, Y)
    tr_X, te_X, tr_Y, te_Y = train_test_split(X, Y, train_size = 0.7, random_state = 42)
    
    # Reshape training and test X into (n_samples, n_features)
    tr_X = tr_X.reshape(tr_X.shape[0], tr_X.shape[1]*tr_X.shape[2])
    te_X = te_X.reshape(te_X.shape[0], te_X.shape[1]*te_X.shape[2])
    
    # Unzipped training and test Y from (n_samples,) into (n_samples)
    tr_Y = list(zip(*tr_Y))[0]
    te_Y = list(zip(*te_Y))[0]
    
    return tr_X, te_X, tr_Y, te_Y

# input the landmarks, gender(output of extract_features_labels() to get_data
# feature as X,label as Y
tr_feature, te_feature, tr_label, te_label = get_data(landmarks, gender)
#  tr_label and te_label are tuples
print(tr_feature.shape)
print(te_feature.shape)
# Out:
# (3356, 136)
# (1439, 136)

# %% [markdown]
# ## a)(ii) Fit SVM model to the training data
# Fit 3 different Support Vector Classifier (SVC) such as polynomial, rbf and linear kernel to the training data
#
# Implement SVM using SVC() function from the scikit-learn library:
#
# class sklearn.svm.SVC(*, C=1.0, kernel='rbf', degree=3, gamma='scale', coef0=0.0, shrinking=True, probability=False, tol=0.001, cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape='ovr', break_ties=False, random_state=None)

# %%
# Linear kernel SVM
def SVM_linear_modle(x_train,y_train, x_test):
    model = SVC(kernel='linear')
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    return y_pred

# Scikit learn library results by using training data: tr_feature and tr_label to get label_pred
label_pred=SVM_linear_modle(tr_feature,tr_label, te_feature)
# Compare te_label and label_pred
print('accuracy score by SVM using image features dataset:',accuracy_score(te_label,label_pred))
# Out:
# accuracy score by SVM using image features dataset: 0.9131341209173037

# %% [markdown]
# ## a)(iii) Fit SVM model with polynomial, rbf and linear kernel to the training data
# ### Experiment with different kernels
#
# use the following 3 different kernel functions implemented in the scikit learn library:
# 1. linear: \begin{align} <x,x'> \end{align}
#
# 2. polynomial: \begin{align} (\gamma <x,x'> +r)^d\end{align}
#
# 3. rbf:\begin{align}e^{(-\gamma||x-x'||^2)} \end{align}

# %%
# Linear kernel SVM
def SVM_linear(x_train, y_train, x_test):
    model = SVC(C = 1.0, kernel = 'linear', degree = 3, gamma = 'scale')
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    return y_pred

# Polynomial kernel SVM
def SVM_poly(x_train, y_train, x_test, d):
    model = SVC(C = 1.0, kernel = 'poly', degree = 3, gamma = 'scale')
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    return y_pred

# Radial basis function kernel SVM
def SVM_rbf(x_train, y_train, x_test):
    model = SVC(C = 1.0, kernel = 'rbf', degree = 3, gamma = 'scale')
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    return y_pred 


# Result of classifier for linear SVM
y_pred1 = SVM_linear(tr_feature, tr_label, te_feature)
print()
print('Linear kernel SVC')
print()
print('Accuracy of classifier: ', accuracy_score(te_label,y_pred1))
print()
print('Confusion matrix: \n', confusion_matrix(te_label,y_pred1))
print()
print(classification_report(te_label,y_pred1))

# Result of classifier for polynomial SVM
y_pred2 = SVM_poly(tr_feature, tr_label, te_feature, 3)
print('Polynomial kernel SVC')
print()
print('Accuracy of classifier: ', accuracy_score(te_label,y_pred2))
print()
print('Confusion matrix: \n', confusion_matrix(te_label,y_pred2))
print()
print(classification_report(te_label,y_pred2))

              
# Result of classifier for RBF SVM
y_pred3 = SVM_rbf(tr_feature, tr_label, te_feature)
print()
print('RBF kernel SVC')
print()
print('Accuracy of classifier: ', accuracy_score(te_label,y_pred3))
print()
print('Confusion matrix: \n', confusion_matrix(te_label,y_pred3))
print()
print(classification_report(te_label,y_pred3))
# Out:
# Linear kernel SVC
#
# Accuracy of classifier:  0.9131341209173037
#
# Confusion matrix:
#  [[643  64]
#  [ 61 671]]
#
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.91      0.91       707
#          1.0       0.91      0.92      0.91       732
#
#     accuracy                           0.91      1439
#    macro avg       0.91      0.91      0.91      1439
# weighted avg       0.91      0.91      0.91      1439
#
# Polynomial kernel SVC
#
# Accuracy of classifier:  0.9047949965253649
#
# Confusion matrix:
#  [[646  61]
#  [ 76 656]]
#
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.91      0.90       707
#          1.0       0.91      0.90      0.91       732
#
#     accuracy                           0.90      1439
#    macro avg       0.90      0.90      0.90      1439
# weighted avg       0.91      0.90      0.90      1439
#
#
# RBF kernel SVC
#
# Accuracy of classifier:  0.8387769284225156
#
# Confusion matrix:
#  [[643  64]
#  [168 564]]
#
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.91      0.85       707
#          1.0       0.90      0.77      0.83       732
#
#     accuracy                           0.84      1439
#    macro avg       0.85      0.84      0.84      1439
# weighted avg       0.85      0.84      0.84      1439

# %% [markdown]
# ## b)(i) Load the iris dataset as training data
# We are going to use the iris dataset
#
# uses a subset of the celeba dataset and labels.csv file which contains the associated labels (1 for female and −1 for male).

# %%
# Loading the data file
data = load_iris()
# print(data)
df=pd.DataFrame(data.data,columns=data.feature_names)
# print(df.head())

# Drop rest of the features and extract the target values
Y_iris = data.target
X_iris = data.data[:, :2]
# print(X)
# print(Y)

# Shuffle and split the data into training and test set
X_iris, Y_iris = shuffle(X_iris,Y_iris)
x_train_iris, x_test_iris, y_train_iris, y_test_iris = train_test_split(X_iris, Y_iris, train_size=0.7)

# %% [markdown]
# ## b)(ii) Implement SVM using SVC() function to the training iris data

# %%
def SVM(x_train_iris,y_train_iris, x_test_iris):
    model = SVC(kernel='linear')
    model.fit(x_train_iris,y_train_iris)
    y_pred_iris = model.predict(x_test_iris)
    return y_pred_iris
# Scikit learn library results
y_pred_iris=SVM(x_train_iris,y_train_iris, x_test_iris)
print('accuracy score by SVM using iris dataset:', accuracy_score(y_test_iris,y_pred_iris))
# Out:
# accuracy score by SVM using iris dataset: 0.7333333333333333

# %% [markdown]
# # 3) Hyperparameter tuning for SVC (Support Vector Classifiers)

# %% [markdown]
# ## a) SVC with linear kernel
# \begin{align} <x,x'> \end{align}
#
# Hyperparameter is only **C**

# %%
# Set the parameters by cross-validation
tuned_parameters = [{'kernel': ['linear'], 'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000]}]

scores = ['precision', 'recall']

for score in scores:
    print("Tuning hyper-parameters for SVC with linear kernel %s" % score)
    print()

    clf = GridSearchCV(SVC(), tuned_parameters, cv=5,scoring='%s_macro' % score)
    clf.fit(tr_feature, tr_label)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = te_label, clf.predict(te_feature)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# Tuning hyper-parameters for SVC with linear kernel precision
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 11
#       8 print()
#      10 clf = GridSearchCV(SVC(), tuned_parameters, cv=5,scoring='%s_macro' % score)
# ---> 11 clf.fit(tr_feature, tr_label)
#      13 print("Best parameters set found on development set:")
#      14 print()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:891, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     885     results = self._format_results(
#     886         all_candidate_params, n_splits, all_out, all_more_results
#     887     )
#     889     return results
# --> 891 self._run_search(evaluate_candidates)
#     893 # multimetric is determined here because in the case of a callable
#     894 # self.scoring the return type is only known after calling
#     895 first_test_score = all_out[0]["test_scores"]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:1392, in GridSearchCV._run_search(self, evaluate_candidates)
#    1390 def _run_search(self, evaluate_candidates):
#    1391     """Search all candidates in param_grid"""
# -> 1392     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:838, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     830 if self.verbose > 0:
#     831     print(
#     832         "Fitting {0} folds for each of {1} candidates,"
#     833         " totalling {2} fits".format(
#     834             n_splits, n_candidates, n_candidates * n_splits
#     835         )
#     836     )
# --> 838 out = parallel(
#     839     delayed(_fit_and_score)(
#     840         clone(base_estimator),
#     841         X,
#     842         y,
#     843         train=train,
#     844         test=test,
#     845         parameters=parameters,
#     846         split_progress=(split_idx, n_splits),
#     847         candidate_progress=(cand_idx, n_candidates),
#     848         **fit_and_score_kwargs,
#     849     )
#     850     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     851         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     852     )
#     853 )
#     855 if len(out) < 1:
#     856     raise ValueError(
#     857         "No fits were performed. "
#     858         "Was the CV iterator empty? "
#     859         "Were there no candidates?"
#     860     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:1051, in Parallel.__call__(self, iterable)
#    1048 if self.dispatch_one_batch(iterator):
#    1049     self._iterating = self._original_iterator is not None
# -> 1051 while self.dispatch_one_batch(iterator):
#    1052     pass
#    1054 if pre_dispatch == "all" or n_jobs == 1:
#    1055     # The iterable was consumed all at once by the above for loop.
#    1056     # No need to wait for async callbacks to trigger to
#    1057     # consumption.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:864, in Parallel.dispatch_one_batch(self, iterator)
#     862     return False
#     863 else:
# --> 864     self._dispatch(tasks)
#     865     return True
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:782, in Parallel._dispatch(self, batch)
#     780 with self._lock:
#     781     job_idx = len(self._jobs)
# --> 782     job = self._backend.apply_async(batch, callback=cb)
#     783     # A job can complete so quickly than its callback is
#     784     # called before we get here, causing self._jobs to
#     785     # grow. To ensure correct results ordering, .insert is
#     786     # used (rather than .append) in the following line
#     787     self._jobs.insert(job_idx, job)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:263, in BatchedCalls.__call__(self)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/joblib/parallel.py:263, in <listcomp>(.0)
#     259 def __call__(self):
#     260     # Set the default nested backend to self._backend but do not set the
#     261     # change the default number of processes to -1
#     262     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 263         return [func(*args, **kwargs)
#     264                 for func, args, kwargs in self.items]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/fixes.py:216, in _FuncWrapper.__call__(self, *args, **kwargs)
#     214 def __call__(self, *args, **kwargs):
#     215     with config_context(**self.config):
# --> 216         return self.function(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:680, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678         estimator.fit(X_train, **fit_params)
#     679     else:
# --> 680         estimator.fit(X_train, y_train, **fit_params)
#     682 except Exception:
#     683     # Note fit time as time until error
#     684     fit_time = time.time() - start_time
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:255, in BaseLibSVM.fit(self, X, y, sample_weight)
#     252     print("[LibSVM]", end="")
#     254 seed = rnd.randint(np.iinfo("i").max)
# --> 255 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     256 # see comment on the other call to np.iinfo in this file
#     258 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:315, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     302 libsvm.set_verbosity_wrap(self.verbose)
#     304 # we don't pass **self.get_params() to allow subclasses to
#     305 # add other parameters to __init__
#     306 (
#     307     self.support_,
#     308     self.support_vectors_,
#     309     self._n_support,
#     310     self.dual_coef_,
#     311     self.intercept_,
#     312     self._probA,
#     313     self._probB,
#     314     self.fit_status_,
# --> 315 ) = libsvm.fit(
#     316     X,
#     317     y,
#     318     svm_type=solver_type,
#     319     sample_weight=sample_weight,
#     320     class_weight=self.class_weight_,
#     321     kernel=kernel,
#     322     C=self.C,
#     323     nu=self.nu,
#     324     probability=self.probability,
#     325     degree=self.degree,
#     326     shrinking=self.shrinking,
#     327     tol=self.tol,
#     328     cache_size=self.cache_size,
#     329     coef0=self.coef0,
#     330     gamma=self._gamma,
#     331     epsilon=self.epsilon,
#     332     max_iter=self.max_iter,
#     333     random_seed=random_seed,
#     334 )
#     336 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %% [markdown]
# ## b) SVC with polynomial kernel
#  \begin{align} (\gamma <x,x'> +r)^d\end{align}
#
#  Hyperparameter are **C**, **gamma**, **coefficient** and **degree**

# %%
# Set the parameters by cross-validation
tuned_parameters = [{'kernel': ['poly'], 'degree': [2, 3, 4], 'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000]}]

scores = ['precision', 'recall']

for score in scores:
    print("Tuning hyper-parameters for SVC with polynomial kernel %s" % score)
    print()

    clf = GridSearchCV(SVC(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(tr_feature, tr_label)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = te_label, clf.predict(te_feature)
    print(classification_report(y_true, y_pred))
    print()

# %% [markdown]
# ## c) SVC with RBF kernel
# \begin{align}e^{(-\gamma||x-x'||^2)} \end{align}
#
# Hyperparameter are **C** and **gamma**

# %%
# Set the parameters by cross-validation
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4], 'C': [1, 10, 100, 1000]}]

scores = ['precision', 'recall']

for score in scores:
    print("Tuning hyper-parameters for SVC with RBF kernel %s" % score)
    print()

    clf = GridSearchCV(SVC(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(tr_feature, tr_label)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    
    y_true, y_pred = te_label, clf.predict(te_feature)
    print(classification_report(y_true, y_pred))
    print()

# %% [markdown]
# # 4) Plot learning curve
# 学习曲线就是通过画出不同训练集大小时训练集和交叉验证的准确率，可以看到模型在新数据上的表现，进而来判断模型是否方差偏高或偏差过高，以及增大训练集是否可以减小过拟合。

# %% [markdown]
# ## a) Learning curve for Linear kernel SVC

# %%
# Create a SVM classifier with a linear kernel
svmlinear = SVC(kernel='linear')

# Generate the training and test sets sizes
train_sizes, train_scores, test_scores = learning_curve(svm, tr_feature, tr_label, cv=10, n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5))

# Plot the learning curve
plt.figure()
plt.title("Learning Curve (Linear Kernel SVC)")
plt.xlabel("Training Examples")
plt.ylabel("Score")

train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.grid()
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.1, color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
plt.legend(loc="best")

svmlinear.fit(tr_feature,tr_label)
ypred=svmlinear.predict(te_feature)
score=accuracy_score(y_pred,te_label)
display('Score using linear kernel function：',score)

plt.show()

# %% [markdown]
# ## c) Learning curve for Polynomial kernel SVC

# %%
# Create a SVM classifier with a linear kernel
svmploy = SVC(kernel='poly', degree=2)
cv = ShuffleSplit(n_splits=50, test_size=0.2, random_state=0)

# Generate the training and test sets sizes
train_sizes, train_scores, test_scores = learning_curve(svmploy, tr_feature, tr_label, cv=cv, n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5))

# Plot the learning curve
plt.figure()
plt.title("Learning Curve (Polynomial Kernel SVC)")
plt.xlabel("Training Examples")
plt.ylabel("Score")

train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)

plt.grid()
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.1, color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
plt.legend(loc="best")

svmploy.fit(tr_feature,tr_label)
ypred=svmploy.predict(te_feature)
score=accuracy_score(y_pred,te_label)
display('Score using ploy kernel function：',score)
plt.show()

# %% [markdown]
# ## c) Learning curve for RBF kernel SVC

# %%
# Create a SVM classifier with a rbf kernel
svmrbf = SVC(kernel='rbf',degree=2)

# Generate the training and test sets sizes
train_sizes, train_scores, test_scores = learning_curve(svmrbf, X, y, cv=10, n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5))
# Plot the learning curve
plt.figure()
plt.title("Learning Curve (RBF Kernel SVC)")
plt.xlabel("Training Examples")
plt.ylabel("Score")

train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)


plt.grid()
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.1, color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
plt.legend(loc="best")

svmrbf.fit(tr_feature,tr_label)
ypred=svmrbf.predict(te_feature)
score=accuracy_score(y_pred,te_label)
display('Score using RBF kernel function：', score)

plt.show()

# %% [markdown]
# # 5) Loading Zlatan Ibrahimovic

# %%
# Modified the directory
Abasedir_test = os.path.join(AMLS_dir,'dataset_AMLS_22-23_test')


basedir_test = os.path.join(AMLS_dir,'dataset_AMLS_22-23_test')
celeba_test_dir = os.path.join(basedir_test,'celeba_test')
images_test_dir = os.path.join(celeba_test_dir,'img')

# labels = os.path.join(base_dir,'celeba/labels.csv') #倒入标签文件csv

# %%
img_test = os.path.join(images_test_dir, '100.jpg')
load_test_img = image.img_to_array(image.load_img(img_test,
                               target_size = None,
                               interpolation = 'bicubic'))
img_test_features, _ = run_dlib_shape(load_test_img)
print(ex_img)

# Load image using cv2
actual_test_img = cv2.imread(test_img)
fig = plt.figure(figsize = (7,7))
fig_plot = plt.imshow(actual_test_img)
plt.title('Extracted Feature Images with Landmarks')
plt.scatter(img_test_features[:,0], img_test_features[:,1], c = 'r')
# Out:
# /Users/liujia/Desktop/AMLS_22-23_SN22126076/Datasets/celeba/img/5.jpg
# [ WARN:0@1515.314] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/Users/liujia/Desktop/AMLS_22-23_SN22126076/Datasets/celeba_test/img/100.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 11
#       9 actual_test_img = cv2.imread(test_img)
#      10 fig = plt.figure(figsize = (7,7))
# ---> 11 fig_plot = plt.imshow(actual_test_img)
#      12 plt.title('Extracted Feature Images with Landmarks')
#      13 plt.scatter(img_test_features[:,0], img_test_features[:,1], c = 'r')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2623, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2617 @_copy_docstring_and_deprecators(Axes.imshow)
#    2618 def imshow(
#    2619         X, cmap=None, norm=None, aspect=None, interpolation=None,
#    2620         alpha=None, vmin=None, vmax=None, origin=None, extent=None, *,
#    2621         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2622         resample=None, url=None, data=None, **kwargs):
# -> 2623     __ret = gca().imshow(
#    2624         X, cmap=cmap, norm=norm, aspect=aspect,
#    2625         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2626         vmax=vmax, origin=origin, extent=extent,
#    2627         interpolation_stage=interpolation_stage,
#    2628         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2629         url=url, **({"data": data} if data is not None else {}),
#    2630         **kwargs)
#    2631     sci(__ret)
#    2632     return __ret
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:5604, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5596 self.set_aspect(aspect)
#    5597 im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    5598                       interpolation=interpolation, origin=origin,
#    5599                       extent=extent, filternorm=filternorm,
#    5600                       filterrad=filterrad, resample=resample,
#    5601                       interpolation_stage=interpolation_stage,
#    5602                       **kwargs)
# -> 5604 im.set_data(X)
#    5605 im.set_alpha(alpha)
#    5606 if im.get_clip_path() is None:
#    5607     # image does not already have clipping set, clip to axes patch
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/image.py:701, in _ImageBase.set_data(self, A)
#     697 self._A = cbook.safe_masked_invalid(A, copy=True)
#     699 if (self._A.dtype != np.uint8 and
#     700         not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 701     raise TypeError("Image data of dtype {} cannot be converted to "
#     702                     "float".format(self._A.dtype))
#     704 if self._A.ndim == 3 and self._A.shape[-1] == 1:
#     705     # If just one dimension assume scalar and apply colormap
#     706     self._A = self._A[:, :, 0]
#
# TypeError: Image data of dtype object cannot be converted to float
